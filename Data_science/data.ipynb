# %%
# !pip install matplotlib seaborn
#  Imports necessários. 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python312\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\daniel\appdata\roaming\python\python312\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\daniel\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\python312\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\daniel\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.9.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Installing collected packages: cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.2.1 cycler-0.12.1 matplotlib-3.9.0 seaborn-0.13.2

# %%
# Lendo a base de dados utilizada.

obesityDataSet = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv', sep=',')
display(obesityDataSet)

obesityDataSet.shape
# Out:
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP  \
# 0     21.000000  Female  1.620000   64.000000          no   no   2.0  3.0
# 1     21.000000  Female  1.520000   56.000000   Sometimes   no   3.0  3.0
# 2     23.000000    Male  1.800000   77.000000  Frequently   no   2.0  3.0
# 3     27.000000    Male  1.800000   87.000000  Frequently   no   3.0  3.0
# 4     22.000000    Male  1.780000   89.800000   Sometimes   no   2.0  1.0
# ...         ...     ...       ...         ...         ...  ...   ...  ...
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0
#
#       SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# 0      no    no  2.000000                            yes  0.000000  1.000000
# 1     yes   yes  3.000000                            yes  3.000000  0.000000
# 2      no    no  2.000000                            yes  2.000000  1.000000
# 3      no    no  2.000000                             no  2.000000  0.000000
# 4      no    no  2.000000                             no  0.000000  0.000000
# ...   ...   ...       ...                            ...       ...       ...
# 2106   no    no  1.728139                            yes  1.676269  0.906247
# 2107   no    no  2.005130                            yes  1.341390  0.599270
# 2108   no    no  2.054193                            yes  1.414209  0.646288
# 2109   no    no  2.852339                            yes  1.139107  0.586035
# 2110   no    no  2.863513                            yes  1.026452  0.714137
#
#            CAEC                 MTRANS           NObeyesdad
# 0     Sometimes  Public_Transportation        Normal_Weight
# 1     Sometimes  Public_Transportation        Normal_Weight
# 2     Sometimes  Public_Transportation        Normal_Weight
# 3     Sometimes                Walking   Overweight_Level_I
# 4     Sometimes  Public_Transportation  Overweight_Level_II
# ...         ...                    ...                  ...
# 2106  Sometimes  Public_Transportation     Obesity_Type_III
# 2107  Sometimes  Public_Transportation     Obesity_Type_III
# 2108  Sometimes  Public_Transportation     Obesity_Type_III
# 2109  Sometimes  Public_Transportation     Obesity_Type_III
# 2110  Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]
# (2111, 17)

# %%
# Checando tipos das colunas presentes.

obesityDataSet.dtypes
# Out:
# Age                               float64
# Gender                             object
# Height                            float64
# Weight                            float64
# CALC                               object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# SCC                                object
# SMOKE                              object
# CH2O                              float64
# family_history_with_overweight     object
# FAF                               float64
# TUE                               float64
# CAEC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
# Buscando por valores nulos.
obesityDataSet.isnull().sum()
# Out:
# Age                               0
# Gender                            0
# Height                            0
# Weight                            0
# CALC                              0
# FAVC                              0
# FCVC                              0
# NCP                               0
# SCC                               0
# SMOKE                             0
# CH2O                              0
# family_history_with_overweight    0
# FAF                               0
# TUE                               0
# CAEC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
obesityDataSet.nunique()
# Out:
# Age                               1402
# Gender                               2
# Height                            1574
# Weight                            1525
# CALC                                 4
# FAVC                                 2
# FCVC                               810
# NCP                                635
# SCC                                  2
# SMOKE                                2
# CH2O                              1268
# family_history_with_overweight       2
# FAF                               1190
# TUE                               1129
# CAEC                                 4
# MTRANS                               5
# NObeyesdad                           7
# dtype: int64

# %%
# Verificando se ha alguma categoria ´NObeyesdad´ diferente das categorias padrão.
subset = obesityDataSet.loc[~obesityDataSet['NObeyesdad'].isin(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Overweight_Level_III', 'Obesity_Type_III', 'Obesity_Type_II', 'Obesity_Type_I'])]

display(subset)
# Out:
#            Age  Gender    Height     Weight       CALC FAVC      FCVC  \
# 59   20.000000    Male  1.760000  55.000000         no  yes  2.000000
# 71   22.000000  Female  1.670000  50.000000  Sometimes   no  3.000000
# 75   23.000000  Female  1.630000  45.000000         no   no  3.000000
# 76   24.000000  Female  1.600000  45.000000         no   no  2.000000
# 83   19.000000  Female  1.600000  45.000000         no   no  3.000000
# ..         ...     ...       ...        ...        ...  ...       ...
# 740  19.000000  Female  1.531610  42.000000  Sometimes  yes  2.749268
# 741  19.434709  Female  1.525691  42.000000  Sometimes  yes  3.000000
# 742  18.000000    Male  1.719827  52.289828  Sometimes  yes  1.202075
# 743  18.381382    Male  1.722547  53.783977  Sometimes  yes  2.000000
# 744  18.000000    Male  1.738702  50.248677  Sometimes  yes  1.871213
#
#           NCP  SCC SMOKE      CH2O family_history_with_overweight       FAF  \
# 59   4.000000   no    no  3.000000                            yes  2.000000
# 71   3.000000  yes    no  3.000000                            yes  2.000000
# 75   3.000000  yes    no  3.000000                            yes  2.000000
# 76   3.000000   no    no  2.000000                            yes  1.000000
# 83   3.000000  yes    no  3.000000                             no  2.000000
# ..        ...  ...   ...       ...                            ...       ...
# 740  1.394539   no    no  1.322048                             no  0.463949
# 741  1.000000   no    no  1.764055                             no  0.000000
# 742  3.000000   no    no  1.927976                            yes  0.023574
# 743  3.131032   no    no  2.072194                            yes  1.487987
# 744  3.000000   no    no  1.283738                            yes  0.684879
#
#           TUE        CAEC                 MTRANS           NObeyesdad
# 59   2.000000   Sometimes  Public_Transportation  Insufficient_Weight
# 71   1.000000          no  Public_Transportation  Insufficient_Weight
# 75   0.000000   Sometimes  Public_Transportation  Insufficient_Weight
# 76   0.000000          no  Public_Transportation  Insufficient_Weight
# 83   0.000000          no                Walking  Insufficient_Weight
# ..        ...         ...                    ...                  ...
# 740  0.800993  Frequently  Public_Transportation  Insufficient_Weight
# 741  0.560887  Frequently  Public_Transportation  Insufficient_Weight
# 742  1.747256   Sometimes  Public_Transportation  Insufficient_Weight
# 743  2.000000   Sometimes  Public_Transportation  Insufficient_Weight
# 744  1.487223   Sometimes  Public_Transportation  Insufficient_Weight
#
# [272 rows x 17 columns]

# %%
# Abstraindo as linhas: Deixa-mos somente as linhas que nos interessam.
obesityTypeDataSet = obesityDataSet.loc[(obesityDataSet['NObeyesdad'] != 'Normal_Weight') & (obesityDataSet['NObeyesdad'] != 'Overweight_Level_I') & (obesityDataSet['NObeyesdad'] != 'Overweight_Level_II') & (obesityDataSet['NObeyesdad'] != 'Overweight_Level_III') & (obesityDataSet['NObeyesdad'] != 'Insufficient_Weight')]
display(obesityTypeDataSet)
# Out:
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP SCC  \
# 10    26.000000    Male  1.850000  105.000000   Sometimes  yes   3.0  3.0  no
# 13    41.000000    Male  1.800000   99.000000  Frequently  yes   2.0  3.0  no
# 17    29.000000  Female  1.530000   78.000000          no  yes   2.0  1.0  no
# 21    52.000000  Female  1.690000   87.000000          no  yes   3.0  1.0  no
# 23    22.000000  Female  1.600000   82.000000   Sometimes  yes   1.0  1.0  no
# ...         ...     ...       ...         ...         ...  ...   ...  ...  ..
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0  no
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0  no
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0  no
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0  no
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0  no
#
#      SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# 10      no  3.000000                            yes  2.000000  2.000000
# 13      no  2.000000                             no  2.000000  1.000000
# 17      no  2.000000                             no  0.000000  0.000000
# 21     yes  2.000000                            yes  0.000000  0.000000
# 23      no  2.000000                            yes  0.000000  2.000000
# ...    ...       ...                            ...       ...       ...
# 2106    no  1.728139                            yes  1.676269  0.906247
# 2107    no  2.005130                            yes  1.341390  0.599270
# 2108    no  2.054193                            yes  1.414209  0.646288
# 2109    no  2.852339                            yes  1.139107  0.586035
# 2110    no  2.863513                            yes  1.026452  0.714137
#
#             CAEC                 MTRANS        NObeyesdad
# 10    Frequently  Public_Transportation    Obesity_Type_I
# 13     Sometimes             Automobile    Obesity_Type_I
# 17     Sometimes             Automobile    Obesity_Type_I
# 21     Sometimes             Automobile    Obesity_Type_I
# 23     Sometimes  Public_Transportation    Obesity_Type_I
# ...          ...                    ...               ...
# 2106   Sometimes  Public_Transportation  Obesity_Type_III
# 2107   Sometimes  Public_Transportation  Obesity_Type_III
# 2108   Sometimes  Public_Transportation  Obesity_Type_III
# 2109   Sometimes  Public_Transportation  Obesity_Type_III
# 2110   Sometimes  Public_Transportation  Obesity_Type_III
#
# [972 rows x 17 columns]

# %%
# Criando coluna ´imc´: Indice de massa corpórea.
obesityTypeDataSet.loc[:,'imc'] = (obesityTypeDataSet['Weight']) / (obesityTypeDataSet['Height'] ** 2)

display(obesityTypeDataSet)
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_6568\567057699.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obesityTypeDataSet.loc[:,'imc'] = (obesityTypeDataSet['Weight']) / (obesityTypeDataSet['Height'] ** 2)
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP SCC  \
# 10    26.000000    Male  1.850000  105.000000   Sometimes  yes   3.0  3.0  no
# 13    41.000000    Male  1.800000   99.000000  Frequently  yes   2.0  3.0  no
# 17    29.000000  Female  1.530000   78.000000          no  yes   2.0  1.0  no
# 21    52.000000  Female  1.690000   87.000000          no  yes   3.0  1.0  no
# 23    22.000000  Female  1.600000   82.000000   Sometimes  yes   1.0  1.0  no
# ...         ...     ...       ...         ...         ...  ...   ...  ...  ..
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0  no
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0  no
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0  no
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0  no
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0  no
#
#      SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# 10      no  3.000000                            yes  2.000000  2.000000
# 13      no  2.000000                             no  2.000000  1.000000
# 17      no  2.000000                             no  0.000000  0.000000
# 21     yes  2.000000                            yes  0.000000  0.000000
# 23      no  2.000000                            yes  0.000000  2.000000
# ...    ...       ...                            ...       ...       ...
# 2106    no  1.728139                            yes  1.676269  0.906247
# 2107    no  2.005130                            yes  1.341390  0.599270
# 2108    no  2.054193                            yes  1.414209  0.646288
# 2109    no  2.852339                            yes  1.139107  0.586035
# 2110    no  2.863513                            yes  1.026452  0.714137
#
#             CAEC                 MTRANS        NObeyesdad        imc
# 10    Frequently  Public_Transportation    Obesity_Type_I  30.679328
# 13     Sometimes             Automobile    Obesity_Type_I  30.555556
# 17     Sometimes             Automobile    Obesity_Type_I  33.320518
# 21     Sometimes             Automobile    Obesity_Type_I  30.461118
# 23     Sometimes  Public_Transportation    Obesity_Type_I  32.031250
# ...          ...                    ...               ...        ...
# 2106   Sometimes  Public_Transportation  Obesity_Type_III  44.901475
# 2107   Sometimes  Public_Transportation  Obesity_Type_III  43.741923
# 2108   Sometimes  Public_Transportation  Obesity_Type_III  43.543817
# 2109   Sometimes  Public_Transportation  Obesity_Type_III  44.071535
# 2110   Sometimes  Public_Transportation  Obesity_Type_III  44.144338
#
# [972 rows x 18 columns]

# %%
# Mudando o tipo das idades de Float para int.
obesityTypeDataSet.loc[:, 'Age'] = obesityTypeDataSet['Age'].astype(int)
display(obesityTypeDataSet)
# Out:
#        Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP SCC  \
# 10    26.0    Male  1.850000  105.000000   Sometimes  yes   3.0  3.0  no
# 13    41.0    Male  1.800000   99.000000  Frequently  yes   2.0  3.0  no
# 17    29.0  Female  1.530000   78.000000          no  yes   2.0  1.0  no
# 21    52.0  Female  1.690000   87.000000          no  yes   3.0  1.0  no
# 23    22.0  Female  1.600000   82.000000   Sometimes  yes   1.0  1.0  no
# ...    ...     ...       ...         ...         ...  ...   ...  ...  ..
# 2106  20.0  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0  no
# 2107  21.0  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0  no
# 2108  22.0  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0  no
# 2109  24.0  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0  no
# 2110  23.0  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0  no
#
#      SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# 10      no  3.000000                            yes  2.000000  2.000000
# 13      no  2.000000                             no  2.000000  1.000000
# 17      no  2.000000                             no  0.000000  0.000000
# 21     yes  2.000000                            yes  0.000000  0.000000
# 23      no  2.000000                            yes  0.000000  2.000000
# ...    ...       ...                            ...       ...       ...
# 2106    no  1.728139                            yes  1.676269  0.906247
# 2107    no  2.005130                            yes  1.341390  0.599270
# 2108    no  2.054193                            yes  1.414209  0.646288
# 2109    no  2.852339                            yes  1.139107  0.586035
# 2110    no  2.863513                            yes  1.026452  0.714137
#
#             CAEC                 MTRANS        NObeyesdad        imc
# 10    Frequently  Public_Transportation    Obesity_Type_I  30.679328
# 13     Sometimes             Automobile    Obesity_Type_I  30.555556
# 17     Sometimes             Automobile    Obesity_Type_I  33.320518
# 21     Sometimes             Automobile    Obesity_Type_I  30.461118
# 23     Sometimes  Public_Transportation    Obesity_Type_I  32.031250
# ...          ...                    ...               ...        ...
# 2106   Sometimes  Public_Transportation  Obesity_Type_III  44.901475
# 2107   Sometimes  Public_Transportation  Obesity_Type_III  43.741923
# 2108   Sometimes  Public_Transportation  Obesity_Type_III  43.543817
# 2109   Sometimes  Public_Transportation  Obesity_Type_III  44.071535
# 2110   Sometimes  Public_Transportation  Obesity_Type_III  44.144338
#
# [972 rows x 18 columns]

# %%
# Separando dataSet por Categoria ´NObeyesdad´.
obesityLevel_I = obesityTypeDataSet.loc[obesityTypeDataSet['NObeyesdad'] == 'Obesity_Type_I']
display(obesityLevel_I)
# Out:
#        Age  Gender    Height      Weight        CALC FAVC      FCVC       NCP  \
# 10    26.0    Male  1.850000  105.000000   Sometimes  yes  3.000000  3.000000
# 13    41.0    Male  1.800000   99.000000  Frequently  yes  2.000000  3.000000
# 17    29.0  Female  1.530000   78.000000          no  yes  2.000000  1.000000
# 21    52.0  Female  1.690000   87.000000          no  yes  3.000000  1.000000
# 23    22.0  Female  1.600000   82.000000   Sometimes  yes  1.000000  1.000000
# ...    ...     ...       ...         ...         ...  ...       ...       ...
# 1508  20.0    Male  1.705304   99.873716          no  yes  2.000000  1.293342
# 1509  19.0  Female  1.612910   82.193405          no  yes  1.261288  2.930044
# 1510  18.0  Female  1.605469   82.039000          no  yes  2.765330  3.000000
# 1511  18.0    Male  1.804160  104.406820          no  yes  2.000000  3.000000
# 1512  19.0    Male  1.785062  104.187314          no  yes  2.000000  3.000000
#
#      SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# 10    no    no  3.000000                            yes  2.000000  2.000000
# 13    no    no  2.000000                             no  2.000000  1.000000
# 17    no    no  2.000000                             no  0.000000  0.000000
# 21    no   yes  2.000000                            yes  0.000000  0.000000
# 23    no    no  2.000000                            yes  0.000000  2.000000
# ...   ..   ...       ...                            ...       ...       ...
# 1508  no    no  2.000000                            yes  0.000000  1.917679
# 1509  no    no  1.166655                            yes  0.133398  0.951740
# 1510  no    no  1.048584                            yes  0.192559  0.720411
# 1511  no    no  3.000000                            yes  2.240500  0.000000
# 1512  no    no  2.151570                            yes  1.605983  0.000000
#
#             CAEC                 MTRANS      NObeyesdad        imc
# 10    Frequently  Public_Transportation  Obesity_Type_I  30.679328
# 13     Sometimes             Automobile  Obesity_Type_I  30.555556
# 17     Sometimes             Automobile  Obesity_Type_I  33.320518
# 21     Sometimes             Automobile  Obesity_Type_I  30.461118
# 23     Sometimes  Public_Transportation  Obesity_Type_I  32.031250
# ...          ...                    ...             ...        ...
# 1508   Sometimes  Public_Transportation  Obesity_Type_I  34.343740
# 1509   Sometimes  Public_Transportation  Obesity_Type_I  31.594879
# 1510   Sometimes  Public_Transportation  Obesity_Type_I  31.828525
# 1511   Sometimes  Public_Transportation  Obesity_Type_I  32.075894
# 1512   Sometimes  Public_Transportation  Obesity_Type_I  32.697024
#
# [351 rows x 18 columns]

# %%
# Tirando a media de idade por sexo.

mean_age_male_Obesity_I = obesityLevel_I.loc[obesityLevel_I['Gender'] == 'Male', 'Age'].mean().astype(int)


mean_age_female_Obesity_I = obesityLevel_I.loc[obesityLevel_I['Gender'] == 'Female', 'Age'].mean().astype(int)

print("Média de idade entre homens:", mean_age_male_Obesity_I)
print("Média de idade entre mulheres:", mean_age_female_Obesity_I)
# Out:
# Média de idade entre homens: 23
# Média de idade entre mulheres: 27

# %%
# Separando dataSet por Categoria ´NObeyesdad´.
obesityLevel_II = obesityTypeDataSet.loc[obesityTypeDataSet['NObeyesdad'] == 'Obesity_Type_II']
display(obesityLevel_II)
# Out:
#        Age  Gender    Height      Weight        CALC FAVC      FCVC       NCP  \
# 68    30.0    Male  1.760000  112.000000  Frequently  yes  1.000000  3.000000
# 90    25.0  Female  1.630000   93.000000          no   no  3.000000  4.000000
# 165   30.0    Male  1.920000  130.000000   Sometimes   no  2.000000  3.000000
# 197   41.0    Male  1.750000  118.000000   Sometimes  yes  2.000000  3.000000
# 210   20.0    Male  1.800000  114.000000          no  yes  2.000000  3.000000
# ...    ...     ...       ...         ...         ...  ...       ...       ...
# 1794  30.0    Male  1.653876  102.583895          no  yes  2.919526  2.142328
# 1795  20.0    Male  1.657132  105.580491          no  yes  2.724121  1.437959
# 1796  20.0    Male  1.644751  101.067988          no  yes  2.801992  1.343117
# 1797  25.0    Male  1.660761  104.321463          no  yes  2.748971  1.213431
# 1798  26.0    Male  1.691510  102.595180          no  yes  2.680375  1.089048
#
#       SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# 68    yes   yes  2.000000                            yes  0.000000  0.000000
# 90     no    no  1.000000                             no  2.000000  0.000000
# 165    no   yes  1.000000                            yes  1.000000  0.000000
# 197    no    no  2.000000                            yes  0.000000  0.000000
# 210    no    no  2.000000                            yes  0.000000  1.000000
# ...   ...   ...       ...                            ...       ...       ...
# 1794   no    no  1.175714                            yes  0.958555  0.636289
# 1795   no    no  1.590418                            yes  0.029603  1.122118
# 1796   no    no  1.128942                            yes  0.233987  0.819980
# 1797   no    no  1.448875                            yes  0.128548  1.239038
# 1798   no    no  1.366238                            yes  0.181324  1.041677
#
#             CAEC                 MTRANS       NObeyesdad        imc
# 68            no             Automobile  Obesity_Type_II  36.157025
# 90        Always  Public_Transportation  Obesity_Type_II  35.003199
# 165    Sometimes  Public_Transportation  Obesity_Type_II  35.264757
# 197    Sometimes                   Bike  Obesity_Type_II  38.530612
# 210   Frequently  Public_Transportation  Obesity_Type_II  35.185185
# ...          ...                    ...              ...        ...
# 1794   Sometimes  Public_Transportation  Obesity_Type_II  37.503629
# 1795   Sometimes  Public_Transportation  Obesity_Type_II  38.447621
# 1796   Sometimes  Public_Transportation  Obesity_Type_II  37.360554
# 1797   Sometimes  Public_Transportation  Obesity_Type_II  37.823298
# 1798   Sometimes  Public_Transportation  Obesity_Type_II  35.857319
#
# [297 rows x 18 columns]

# %%
# Tirando a media de idade por sexo.

mean_age_male_Obesity_II = obesityLevel_II.loc[obesityLevel_II['Gender'] == 'Male', 'Age'].mean().astype(int)


mean_age_female_Obesity_II = obesityLevel_II.loc[obesityLevel_II['Gender'] == 'Female', 'Age'].mean().astype(int)

print("Média de idade entre homens:", mean_age_male_Obesity_II)
print("Média de idade entre mulheres:", mean_age_female_Obesity_II)
# Out:
# Média de idade entre homens: 27
# Média de idade entre mulheres: 24

# %%
# Separando dataSet por Categoria ´NObeyesdad´.
obesityLevel_III = obesityTypeDataSet.loc[obesityTypeDataSet['NObeyesdad'] == 'Obesity_Type_III']
display(obesityLevel_III)
# Out:
#        Age  Gender    Height      Weight       CALC FAVC  FCVC  NCP SCC SMOKE  \
# 202   26.0  Female  1.560000  102.000000  Sometimes  yes   3.0  3.0  no   yes
# 344   18.0    Male  1.870000  173.000000  Sometimes  yes   3.0  3.0  no    no
# 403   26.0  Female  1.660000  112.000000         no   no   3.0  3.0  no    no
# 498   25.0  Female  1.686306  104.572712  Sometimes  yes   3.0  3.0  no    no
# 499   18.0  Female  1.683124  126.673780  Sometimes  yes   3.0  3.0  no    no
# ...    ...     ...       ...         ...        ...  ...   ...  ...  ..   ...
# 2106  20.0  Female  1.710730  131.408528  Sometimes  yes   3.0  3.0  no    no
# 2107  21.0  Female  1.748584  133.742943  Sometimes  yes   3.0  3.0  no    no
# 2108  22.0  Female  1.752206  133.689352  Sometimes  yes   3.0  3.0  no    no
# 2109  24.0  Female  1.739450  133.346641  Sometimes  yes   3.0  3.0  no    no
# 2110  23.0  Female  1.738836  133.472641  Sometimes  yes   3.0  3.0  no    no
#
#           CH2O family_history_with_overweight       FAF       TUE        CAEC  \
# 202   1.000000                            yes  0.000000  1.000000   Sometimes
# 344   2.000000                            yes  2.000000  1.000000  Frequently
# 403   3.000000                            yes  0.000000  0.000000   Sometimes
# 498   1.152736                            yes  0.319156  1.000000   Sometimes
# 499   1.115967                            yes  1.541072  1.000000   Sometimes
# ...        ...                            ...       ...       ...         ...
# 2106  1.728139                            yes  1.676269  0.906247   Sometimes
# 2107  2.005130                            yes  1.341390  0.599270   Sometimes
# 2108  2.054193                            yes  1.414209  0.646288   Sometimes
# 2109  2.852339                            yes  1.139107  0.586035   Sometimes
# 2110  2.863513                            yes  1.026452  0.714137   Sometimes
#
#                      MTRANS        NObeyesdad        imc
# 202   Public_Transportation  Obesity_Type_III  41.913215
# 344   Public_Transportation  Obesity_Type_III  49.472390
# 403              Automobile  Obesity_Type_III  40.644506
# 498   Public_Transportation  Obesity_Type_III  36.774400
# 499   Public_Transportation  Obesity_Type_III  44.715131
# ...                     ...               ...        ...
# 2106  Public_Transportation  Obesity_Type_III  44.901475
# 2107  Public_Transportation  Obesity_Type_III  43.741923
# 2108  Public_Transportation  Obesity_Type_III  43.543817
# 2109  Public_Transportation  Obesity_Type_III  44.071535
# 2110  Public_Transportation  Obesity_Type_III  44.144338
#
# [324 rows x 18 columns]

# %%
# Tirando a media de idade por sexo.

mean_age_male_Obesity_III = obesityLevel_III.loc[obesityLevel_III['Gender'] == 'Male', 'Age'].mean().astype(int)


mean_age_female_Obesity_III = obesityLevel_III.loc[obesityLevel_III['Gender'] == 'Female', 'Age'].mean().astype(int)

print("Média de idade entre homens:", mean_age_male_Obesity_III)
print("Média de idade entre mulheres:", mean_age_female_Obesity_III)
# Out:
# Média de idade entre homens: 18
# Média de idade entre mulheres: 23

# %%
# Calculando a média e a mediana da idade por sexo.

mean_obesityData_Man = obesityTypeDataSet.loc[obesityTypeDataSet['Gender'] == 'Male', 'Age'].mean()

mean_obesityData_Woman = obesityTypeDataSet.loc[obesityTypeDataSet['Gender'] == 'Female', 'Age'].mean()


print("Man mean",mean_obesityData_Man)

print("Woman mean",mean_obesityData_Woman)


median_man = np.median(obesityTypeDataSet.loc[obesityTypeDataSet['Gender'] == 'Male', 'Age'])
median_woman = np.median(obesityTypeDataSet.loc[obesityTypeDataSet['Gender'] == 'Female', 'Age'])


print("Man median",mean_obesityData_Man)

print("Woman median",median_woman)

# Ambos os casos mostram que a média é maior do que a mediana. Isso sugere que pode haver alguns valores extremos de idade
# mais altos que estão puxando a média para cima em ambos os grupos (homens e mulheres). Esses valores extremos podem 
# representar uma pequena porcentagem da população, enquanto a maioria das idades está abaixo da média.
# Out:
# Man mean 26.209775967413442
# Woman mean 24.51975051975052
# Man median 26.209775967413442
# Woman median 24.0

# %%
# Criando dataSete para determinada analise.
consumo_de_Alimentos_e_habitos = obesityTypeDataSet[['Age', 'Gender', 'FAVC', 'FCVC', 'NCP', 'family_history_with_overweight', 'imc', 'NObeyesdad']]

display(consumo_de_Alimentos_e_habitos)

consumo_de_Alimentos_e_habitos.shape
# Out:
#        Age  Gender FAVC  FCVC  NCP family_history_with_overweight        imc  \
# 10    26.0    Male  yes   3.0  3.0                            yes  30.679328
# 13    41.0    Male  yes   2.0  3.0                             no  30.555556
# 17    29.0  Female  yes   2.0  1.0                             no  33.320518
# 21    52.0  Female  yes   3.0  1.0                            yes  30.461118
# 23    22.0  Female  yes   1.0  1.0                            yes  32.031250
# ...    ...     ...  ...   ...  ...                            ...        ...
# 2106  20.0  Female  yes   3.0  3.0                            yes  44.901475
# 2107  21.0  Female  yes   3.0  3.0                            yes  43.741923
# 2108  22.0  Female  yes   3.0  3.0                            yes  43.543817
# 2109  24.0  Female  yes   3.0  3.0                            yes  44.071535
# 2110  23.0  Female  yes   3.0  3.0                            yes  44.144338
#
#             NObeyesdad
# 10      Obesity_Type_I
# 13      Obesity_Type_I
# 17      Obesity_Type_I
# 21      Obesity_Type_I
# 23      Obesity_Type_I
# ...                ...
# 2106  Obesity_Type_III
# 2107  Obesity_Type_III
# 2108  Obesity_Type_III
# 2109  Obesity_Type_III
# 2110  Obesity_Type_III
#
# [972 rows x 8 columns]
# (972, 8)

# %%
# Verificando quantidades de linhas de acordo com o critério.
display(consumo_de_Alimentos_e_habitos.loc[consumo_de_Alimentos_e_habitos['FAVC'] == 'yes'])
# Out:
#        Age  Gender FAVC  FCVC  NCP family_history_with_overweight        imc  \
# 10    26.0    Male  yes   3.0  3.0                            yes  30.679328
# 13    41.0    Male  yes   2.0  3.0                             no  30.555556
# 17    29.0  Female  yes   2.0  1.0                             no  33.320518
# 21    52.0  Female  yes   3.0  1.0                            yes  30.461118
# 23    22.0  Female  yes   1.0  1.0                            yes  32.031250
# ...    ...     ...  ...   ...  ...                            ...        ...
# 2106  20.0  Female  yes   3.0  3.0                            yes  44.901475
# 2107  21.0  Female  yes   3.0  3.0                            yes  43.741923
# 2108  22.0  Female  yes   3.0  3.0                            yes  43.543817
# 2109  24.0  Female  yes   3.0  3.0                            yes  44.071535
# 2110  23.0  Female  yes   3.0  3.0                            yes  44.144338
#
#             NObeyesdad
# 10      Obesity_Type_I
# 13      Obesity_Type_I
# 17      Obesity_Type_I
# 21      Obesity_Type_I
# 23      Obesity_Type_I
# ...                ...
# 2106  Obesity_Type_III
# 2107  Obesity_Type_III
# 2108  Obesity_Type_III
# 2109  Obesity_Type_III
# 2110  Obesity_Type_III
#
# [953 rows x 8 columns]

# %%
# Verificando quantidades de linhas de acordo com o critério.

display(consumo_de_Alimentos_e_habitos.loc[(consumo_de_Alimentos_e_habitos['FAVC'] == 'yes') & (consumo_de_Alimentos_e_habitos['family_history_with_overweight'] == 'yes')])
# Out:
#        Age  Gender FAVC  FCVC  NCP family_history_with_overweight        imc  \
# 10    26.0    Male  yes   3.0  3.0                            yes  30.679328
# 21    52.0  Female  yes   3.0  1.0                            yes  30.461118
# 23    22.0  Female  yes   1.0  1.0                            yes  32.031250
# 67    23.0    Male  yes   2.0  3.0                            yes  34.894399
# 68    30.0    Male  yes   1.0  3.0                            yes  36.157025
# ...    ...     ...  ...   ...  ...                            ...        ...
# 2106  20.0  Female  yes   3.0  3.0                            yes  44.901475
# 2107  21.0  Female  yes   3.0  3.0                            yes  43.741923
# 2108  22.0  Female  yes   3.0  3.0                            yes  43.543817
# 2109  24.0  Female  yes   3.0  3.0                            yes  44.071535
# 2110  23.0  Female  yes   3.0  3.0                            yes  44.144338
#
#             NObeyesdad
# 10      Obesity_Type_I
# 21      Obesity_Type_I
# 23      Obesity_Type_I
# 67      Obesity_Type_I
# 68     Obesity_Type_II
# ...                ...
# 2106  Obesity_Type_III
# 2107  Obesity_Type_III
# 2108  Obesity_Type_III
# 2109  Obesity_Type_III
# 2110  Obesity_Type_III
#
# [947 rows x 8 columns]

# %%
display(consumo_de_Alimentos_e_habitos.loc[(consumo_de_Alimentos_e_habitos['FAVC'] == 'yes') & (consumo_de_Alimentos_e_habitos['family_history_with_overweight'] == 'yes')])
# Out:
#        Age  Gender FAVC  FCVC  NCP family_history_with_overweight        imc  \
# 10    26.0    Male  yes   3.0  3.0                            yes  30.679328
# 21    52.0  Female  yes   3.0  1.0                            yes  30.461118
# 23    22.0  Female  yes   1.0  1.0                            yes  32.031250
# 67    23.0    Male  yes   2.0  3.0                            yes  34.894399
# 68    30.0    Male  yes   1.0  3.0                            yes  36.157025
# ...    ...     ...  ...   ...  ...                            ...        ...
# 2106  20.0  Female  yes   3.0  3.0                            yes  44.901475
# 2107  21.0  Female  yes   3.0  3.0                            yes  43.741923
# 2108  22.0  Female  yes   3.0  3.0                            yes  43.543817
# 2109  24.0  Female  yes   3.0  3.0                            yes  44.071535
# 2110  23.0  Female  yes   3.0  3.0                            yes  44.144338
#
#             NObeyesdad
# 10      Obesity_Type_I
# 21      Obesity_Type_I
# 23      Obesity_Type_I
# 67      Obesity_Type_I
# 68     Obesity_Type_II
# ...                ...
# 2106  Obesity_Type_III
# 2107  Obesity_Type_III
# 2108  Obesity_Type_III
# 2109  Obesity_Type_III
# 2110  Obesity_Type_III
#
# [947 rows x 8 columns]

# %%
display(obesityTypeDataSet)
# Out:
#        Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP SCC  \
# 10    26.0    Male  1.850000  105.000000   Sometimes  yes   3.0  3.0  no
# 13    41.0    Male  1.800000   99.000000  Frequently  yes   2.0  3.0  no
# 17    29.0  Female  1.530000   78.000000          no  yes   2.0  1.0  no
# 21    52.0  Female  1.690000   87.000000          no  yes   3.0  1.0  no
# 23    22.0  Female  1.600000   82.000000   Sometimes  yes   1.0  1.0  no
# ...    ...     ...       ...         ...         ...  ...   ...  ...  ..
# 2106  20.0  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0  no
# 2107  21.0  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0  no
# 2108  22.0  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0  no
# 2109  24.0  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0  no
# 2110  23.0  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0  no
#
#      SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# 10      no  3.000000                            yes  2.000000  2.000000
# 13      no  2.000000                             no  2.000000  1.000000
# 17      no  2.000000                             no  0.000000  0.000000
# 21     yes  2.000000                            yes  0.000000  0.000000
# 23      no  2.000000                            yes  0.000000  2.000000
# ...    ...       ...                            ...       ...       ...
# 2106    no  1.728139                            yes  1.676269  0.906247
# 2107    no  2.005130                            yes  1.341390  0.599270
# 2108    no  2.054193                            yes  1.414209  0.646288
# 2109    no  2.852339                            yes  1.139107  0.586035
# 2110    no  2.863513                            yes  1.026452  0.714137
#
#             CAEC                 MTRANS        NObeyesdad        imc
# 10    Frequently  Public_Transportation    Obesity_Type_I  30.679328
# 13     Sometimes             Automobile    Obesity_Type_I  30.555556
# 17     Sometimes             Automobile    Obesity_Type_I  33.320518
# 21     Sometimes             Automobile    Obesity_Type_I  30.461118
# 23     Sometimes  Public_Transportation    Obesity_Type_I  32.031250
# ...          ...                    ...               ...        ...
# 2106   Sometimes  Public_Transportation  Obesity_Type_III  44.901475
# 2107   Sometimes  Public_Transportation  Obesity_Type_III  43.741923
# 2108   Sometimes  Public_Transportation  Obesity_Type_III  43.543817
# 2109   Sometimes  Public_Transportation  Obesity_Type_III  44.071535
# 2110   Sometimes  Public_Transportation  Obesity_Type_III  44.144338
#
# [972 rows x 18 columns]

# %%
obesityTypeDataSet_encoded = pd.get_dummies(obesityTypeDataSet, drop_first=True)
display(obesityTypeDataSet_encoded)
# Out:
#        Age    Height      Weight  FCVC  NCP      CH2O       FAF       TUE  \
# 10    26.0  1.850000  105.000000   3.0  3.0  3.000000  2.000000  2.000000
# 13    41.0  1.800000   99.000000   2.0  3.0  2.000000  2.000000  1.000000
# 17    29.0  1.530000   78.000000   2.0  1.0  2.000000  0.000000  0.000000
# 21    52.0  1.690000   87.000000   3.0  1.0  2.000000  0.000000  0.000000
# 23    22.0  1.600000   82.000000   1.0  1.0  2.000000  0.000000  2.000000
# ...    ...       ...         ...   ...  ...       ...       ...       ...
# 2106  20.0  1.710730  131.408528   3.0  3.0  1.728139  1.676269  0.906247
# 2107  21.0  1.748584  133.742943   3.0  3.0  2.005130  1.341390  0.599270
# 2108  22.0  1.752206  133.689352   3.0  3.0  2.054193  1.414209  0.646288
# 2109  24.0  1.739450  133.346641   3.0  3.0  2.852339  1.139107  0.586035
# 2110  23.0  1.738836  133.472641   3.0  3.0  2.863513  1.026452  0.714137
#
#             imc  Gender_Male  ...  family_history_with_overweight_yes  \
# 10    30.679328         True  ...                                True
# 13    30.555556         True  ...                               False
# 17    33.320518        False  ...                               False
# 21    30.461118        False  ...                                True
# 23    32.031250        False  ...                                True
# ...         ...          ...  ...                                 ...
# 2106  44.901475        False  ...                                True
# 2107  43.741923        False  ...                                True
# 2108  43.543817        False  ...                                True
# 2109  44.071535        False  ...                                True
# 2110  44.144338        False  ...                                True
#
#       CAEC_Frequently  CAEC_Sometimes  CAEC_no  MTRANS_Bike  MTRANS_Motorbike  \
# 10               True           False    False        False             False
# 13              False            True    False        False             False
# 17              False            True    False        False             False
# 21              False            True    False        False             False
# 23              False            True    False        False             False
# ...               ...             ...      ...          ...               ...
# 2106            False            True    False        False             False
# 2107            False            True    False        False             False
# 2108            False            True    False        False             False
# 2109            False            True    False        False             False
# 2110            False            True    False        False             False
#
#       MTRANS_Public_Transportation  MTRANS_Walking  \
# 10                            True           False
# 13                           False           False
# 17                           False           False
# 21                           False           False
# 23                            True           False
# ...                            ...             ...
# 2106                          True           False
# 2107                          True           False
# 2108                          True           False
# 2109                          True           False
# 2110                          True           False
#
#       NObeyesdad_Obesity_Type_II  NObeyesdad_Obesity_Type_III
# 10                         False                        False
# 13                         False                        False
# 17                         False                        False
# 21                         False                        False
# 23                         False                        False
# ...                          ...                          ...
# 2106                       False                         True
# 2107                       False                         True
# 2108                       False                         True
# 2109                       False                         True
# 2110                       False                         True
#
# [972 rows x 25 columns]

# %%
# Calculando a matriz de correlação
correlation_matrix = obesityTypeDataSet_encoded.corr()

# Exibindo a matriz de correlação
display(correlation_matrix)
# Out:
#                                          Age    Height    Weight      FCVC  \
# Age                                 1.000000 -0.197200 -0.291329 -0.130143
# Height                             -0.197200  1.000000  0.639845 -0.107615
# Weight                             -0.291329  0.639845  1.000000  0.394908
# FCVC                               -0.130143 -0.107615  0.394908  1.000000
# NCP                                -0.068696  0.233356  0.401047  0.107565
# CH2O                               -0.154037  0.242227  0.208063  0.046741
# FAF                                -0.108127  0.401622  0.217553 -0.048460
# TUE                                -0.356929  0.138859  0.094388  0.060801
# imc                                -0.225880  0.016166  0.775377  0.616789
# Gender_Male                         0.143427  0.608395  0.050469 -0.439139
# CALC_Sometimes                      0.028052  0.194716  0.460406  0.247413
# CALC_no                            -0.086834 -0.218560 -0.450712 -0.226191
# FAVC_yes                           -0.061690 -0.043645  0.043380  0.039686
# SCC_yes                            -0.028713  0.013207 -0.018441 -0.092700
# SMOKE_yes                           0.119508  0.133984  0.047568 -0.036441
# family_history_with_overweight_yes  0.013506  0.000566  0.073627  0.048031
# CAEC_Frequently                    -0.036701  0.007115 -0.025049 -0.048031
# CAEC_Sometimes                      0.000936 -0.032605  0.039805  0.079871
# CAEC_no                             0.054929  0.027795 -0.001524 -0.046102
# MTRANS_Bike                         0.085122  0.012428  0.016498 -0.032582
# MTRANS_Motorbike                    0.078327 -0.043091 -0.072971 -0.056492
# MTRANS_Public_Transportation       -0.719978  0.072470  0.241508  0.266638
# MTRANS_Walking                     -0.044454  0.017378 -0.026994  0.015923
# NObeyesdad_Obesity_Type_II          0.267680  0.419417  0.237963 -0.166780
# NObeyesdad_Obesity_Type_III        -0.278579 -0.222537  0.483405  0.662491
#
#                                          NCP      CH2O       FAF       TUE  \
# Age                                -0.068696 -0.154037 -0.108127 -0.356929
# Height                              0.233356  0.242227  0.401622  0.138859
# Weight                              0.401047  0.208063  0.217553  0.094388
# FCVC                                0.107565  0.046741 -0.048460  0.060801
# NCP                                 1.000000  0.069235  0.009164 -0.129810
# CH2O                                0.069235  1.000000  0.111427  0.089564
# FAF                                 0.009164  0.111427  1.000000  0.133118
# TUE                                -0.129810  0.089564  0.133118  1.000000
# imc                                 0.344979  0.081638 -0.061672  0.017471
# Gender_Male                        -0.012397 -0.028438  0.256108  0.075418
# CALC_Sometimes                      0.383833  0.133938 -0.180839 -0.130323
# CALC_no                            -0.351040 -0.152800  0.145693  0.129198
# FAVC_yes                           -0.028603 -0.086017 -0.049822  0.006310
# SCC_yes                             0.025472  0.023746 -0.015062  0.006456
# SMOKE_yes                          -0.019783 -0.103707  0.000737  0.049504
# family_history_with_overweight_yes -0.023297  0.029474 -0.029621 -0.003615
# CAEC_Frequently                     0.041704 -0.029474  0.044424  0.024477
# CAEC_Sometimes                     -0.001207  0.053812 -0.012421 -0.015937
# CAEC_no                            -0.052611  0.031768  0.036901 -0.008597
# MTRANS_Bike                         0.014691 -0.003816 -0.036500 -0.035473
# MTRANS_Motorbike                    0.025472  0.023746  0.009050 -0.061504
# MTRANS_Public_Transportation        0.035692  0.088533  0.023763  0.156357
# MTRANS_Walking                      0.025472  0.023746  0.129610  0.074415
# NObeyesdad_Obesity_Type_II          0.029774 -0.211729  0.083621 -0.107127
# NObeyesdad_Obesity_Type_III         0.323711  0.157261 -0.193110  0.001664
#
#                                          imc  Gender_Male  ...  \
# Age                                -0.225880     0.143427  ...
# Height                              0.016166     0.608395  ...
# Weight                              0.775377     0.050469  ...
# FCVC                                0.616789    -0.439139  ...
# NCP                                 0.344979    -0.012397  ...
# CH2O                                0.081638    -0.028438  ...
# FAF                                -0.061672     0.256108  ...
# TUE                                 0.017471     0.075418  ...
# imc                                 1.000000    -0.414173  ...
# Gender_Male                        -0.414173     1.000000  ...
# CALC_Sometimes                      0.441306    -0.207270  ...
# CALC_no                            -0.411333     0.178657  ...
# FAVC_yes                            0.091194    -0.080298  ...
# SCC_yes                            -0.035555     0.017976  ...
# SMOKE_yes                          -0.053626     0.095279  ...
# family_history_with_overweight_yes  0.094470    -0.044614  ...
# CAEC_Frequently                    -0.046227     0.021838  ...
# CAEC_Sometimes                      0.083266    -0.059639  ...
# CAEC_no                            -0.023129     0.044943  ...
# MTRANS_Bike                         0.011105     0.031763  ...
# MTRANS_Motorbike                   -0.063665     0.017976  ...
# MTRANS_Public_Transportation        0.272147    -0.235809  ...
# MTRANS_Walking                     -0.049613     0.017976  ...
# NObeyesdad_Obesity_Type_II         -0.034601     0.647601  ...
# NObeyesdad_Obesity_Type_III         0.827866    -0.710054  ...
#
#                                     family_history_with_overweight_yes  \
# Age                                                           0.013506
# Height                                                        0.000566
# Weight                                                        0.073627
# FCVC                                                          0.048031
# NCP                                                          -0.023297
# CH2O                                                          0.029474
# FAF                                                          -0.029621
# TUE                                                          -0.003615
# imc                                                           0.094470
# Gender_Male                                                  -0.044614
# CALC_Sometimes                                                0.075718
# CALC_no                                                      -0.027829
# FAVC_yes                                                      0.151646
# SCC_yes                                                      -0.200218
# SMOKE_yes                                                    -0.062698
# family_history_with_overweight_yes                            1.000000
# CAEC_Frequently                                              -0.117739
# CAEC_Sometimes                                                0.156415
# CAEC_no                                                       0.004137
# MTRANS_Bike                                                   0.002923
# MTRANS_Motorbike                                              0.005069
# MTRANS_Public_Transportation                                  0.034325
# MTRANS_Walking                                                0.005069
# NObeyesdad_Obesity_Type_II                                    0.035707
# NObeyesdad_Obesity_Type_III                                   0.064416
#
#                                     CAEC_Frequently  CAEC_Sometimes   CAEC_no  \
# Age                                       -0.036701        0.000936  0.054929
# Height                                     0.007115       -0.032605  0.027795
# Weight                                    -0.025049        0.039805 -0.001524
# FCVC                                      -0.048031        0.079871 -0.046102
# NCP                                        0.041704       -0.001207 -0.052611
# CH2O                                      -0.029474        0.053812  0.031768
# FAF                                        0.044424       -0.012421  0.036901
# TUE                                        0.024477       -0.015937 -0.008597
# imc                                       -0.046227        0.083266 -0.023129
# Gender_Male                                0.021838       -0.059639  0.044943
# CALC_Sometimes                            -0.049767        0.092431 -0.076548
# CALC_no                                    0.027829       -0.010861 -0.025785
# FAVC_yes                                   0.012863        0.035728  0.006411
# SCC_yes                                   -0.005069       -0.129930  0.406775
# SMOKE_yes                                  0.062698       -0.081712  0.145738
# family_history_with_overweight_yes        -0.117739        0.156415  0.004137
# CAEC_Frequently                            1.000000       -0.663200 -0.004137
# CAEC_Sometimes                            -0.663200        1.000000 -0.330573
# CAEC_no                                   -0.004137       -0.330573  1.000000
# MTRANS_Bike                               -0.002923        0.004408 -0.001457
# MTRANS_Motorbike                           0.200218       -0.129930 -0.002527
# MTRANS_Public_Transportation              -0.006797        0.056368 -0.085716
# MTRANS_Walking                            -0.005069        0.007643 -0.002527
# NObeyesdad_Obesity_Type_II                -0.035707        0.024849  0.019167
# NObeyesdad_Obesity_Type_III               -0.040260        0.080940 -0.032108
#
#                                     MTRANS_Bike  MTRANS_Motorbike  \
# Age                                    0.085122          0.078327
# Height                                 0.012428         -0.043091
# Weight                                 0.016498         -0.072971
# FCVC                                  -0.032582         -0.056492
# NCP                                    0.014691          0.025472
# CH2O                                  -0.003816          0.023746
# FAF                                   -0.036500          0.009050
# TUE                                   -0.035473         -0.061504
# imc                                    0.011105         -0.063665
# Gender_Male                            0.031763          0.017976
# CALC_Sometimes                         0.019036         -0.051531
# CALC_no                               -0.018223          0.054793
# FAVC_yes                               0.004531         -0.260091
# SCC_yes                               -0.001786         -0.003096
# SMOKE_yes                             -0.004884          0.116234
# family_history_with_overweight_yes     0.002923          0.005069
# CAEC_Frequently                       -0.002923          0.200218
# CAEC_Sometimes                         0.004408         -0.129930
# CAEC_no                               -0.001457         -0.002527
# MTRANS_Bike                            1.000000         -0.001786
# MTRANS_Motorbike                      -0.001786          1.000000
# MTRANS_Public_Transportation          -0.060579         -0.105034
# MTRANS_Walking                        -0.001786         -0.003096
# NObeyesdad_Obesity_Type_II             0.048380         -0.036908
# NObeyesdad_Obesity_Type_III           -0.022692         -0.039344
#
#                                     MTRANS_Public_Transportation  \
# Age                                                    -0.719978
# Height                                                  0.072470
# Weight                                                  0.241508
# FCVC                                                    0.266638
# NCP                                                     0.035692
# CH2O                                                    0.088533
# FAF                                                     0.023763
# TUE                                                     0.156357
# imc                                                     0.272147
# Gender_Male                                            -0.235809
# CALC_Sometimes                                         -0.025174
# CALC_no                                                 0.092299
# FAVC_yes                                                0.158748
# SCC_yes                                                -0.015361
# SMOKE_yes                                              -0.019715
# family_history_with_overweight_yes                      0.034325
# CAEC_Frequently                                        -0.006797
# CAEC_Sometimes                                          0.056368
# CAEC_no                                                -0.085716
# MTRANS_Bike                                            -0.060579
# MTRANS_Motorbike                                       -0.105034
# MTRANS_Public_Transportation                            1.000000
# MTRANS_Walking                                         -0.105034
# NObeyesdad_Obesity_Type_II                             -0.172323
# NObeyesdad_Obesity_Type_III                             0.369312
#
#                                     MTRANS_Walking  \
# Age                                      -0.044454
# Height                                    0.017378
# Weight                                   -0.026994
# FCVC                                      0.015923
# NCP                                       0.025472
# CH2O                                      0.023746
# FAF                                       0.129610
# TUE                                       0.074415
# imc                                      -0.049613
# Gender_Male                               0.017976
# CALC_Sometimes                           -0.051531
# CALC_no                                   0.054793
# FAVC_yes                                 -0.260091
# SCC_yes                                  -0.003096
# SMOKE_yes                                -0.008467
# family_history_with_overweight_yes        0.005069
# CAEC_Frequently                          -0.005069
# CAEC_Sometimes                            0.007643
# CAEC_no                                  -0.002527
# MTRANS_Bike                              -0.001786
# MTRANS_Motorbike                         -0.003096
# MTRANS_Public_Transportation             -0.105034
# MTRANS_Walking                            1.000000
# NObeyesdad_Obesity_Type_II                0.003355
# NObeyesdad_Obesity_Type_III              -0.039344
#
#                                     NObeyesdad_Obesity_Type_II  \
# Age                                                   0.267680
# Height                                                0.419417
# Weight                                                0.237963
# FCVC                                                 -0.166780
# NCP                                                   0.029774
# CH2O                                                 -0.211729
# FAF                                                   0.083621
# TUE                                                  -0.107127
# imc                                                  -0.034601
# Gender_Male                                           0.647601
# CALC_Sometimes                                        0.021915
# CALC_no                                              -0.007369
# FAVC_yes                                             -0.019270
# SCC_yes                                               0.003355
# SMOKE_yes                                             0.124302
# family_history_with_overweight_yes                    0.035707
# CAEC_Frequently                                      -0.035707
# CAEC_Sometimes                                        0.024849
# CAEC_no                                               0.019167
# MTRANS_Bike                                           0.048380
# MTRANS_Motorbike                                     -0.036908
# MTRANS_Public_Transportation                         -0.172323
# MTRANS_Walking                                        0.003355
# NObeyesdad_Obesity_Type_II                            1.000000
# NObeyesdad_Obesity_Type_III                          -0.469042
#
#                                     NObeyesdad_Obesity_Type_III
# Age                                                   -0.278579
# Height                                                -0.222537
# Weight                                                 0.483405
# FCVC                                                   0.662491
# NCP                                                    0.323711
# CH2O                                                   0.157261
# FAF                                                   -0.193110
# TUE                                                    0.001664
# imc                                                    0.827866
# Gender_Male                                           -0.710054
# CALC_Sometimes                                         0.414477
# CALC_no                                               -0.396445
# FAVC_yes                                               0.084078
# SCC_yes                                               -0.039344
# SMOKE_yes                                             -0.092932
# family_history_with_overweight_yes                     0.064416
# CAEC_Frequently                                       -0.040260
# CAEC_Sometimes                                         0.080940
# CAEC_no                                               -0.032108
# MTRANS_Bike                                           -0.022692
# MTRANS_Motorbike                                      -0.039344
# MTRANS_Public_Transportation                           0.369312
# MTRANS_Walking                                        -0.039344
# NObeyesdad_Obesity_Type_II                            -0.469042
# NObeyesdad_Obesity_Type_III                            1.000000
#
# [25 rows x 25 columns]

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlação')
plt.show()
